# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename='dog.jpg'

# %% [markdown]
# # First Method to load an image

# %%
from IPython.display import Image
Image(filename = 'dog.jpg',width=224,height=224)

# %% [markdown]
# # Second Method

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size =(224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# # third method to load image

# %%
import cv2

# %%
img=cv2.imread(filename)

# %%
img=cv2.resize(img,(224,224))

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 4th method

# %%
from PIL import Image

# %%
im=Image.open(filename)

# %%
im=im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # DEEP LEARNING MODEL

# %%
mobile=tf.keras.applications.mobilenet.MobileNet()   ##pretrained model
# Out:
# ...
# 17227776/17225924 [==============================] - 3s 0us/step

# %%
#creating a model
#training
#rest or validate
#predict

# %%
mobile=tf.keras.applications.mobilenet_v2.MobileNetV2()

# %% [markdown]
# # pre processing of image

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size =(224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0)
final_iamge = tf.keras.applications.mobilenet_v2.preprocess_input(final_image)

# %%
resized_img.shape
# Out:
# (224, 224, 3)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions=mobile.predict(final_image)

# %%
print(predictions)
# Out:
# [[1.60527325e-05 4.75760571e-05 9.79227625e-05 3.78659897e-05
#   2.76025734e-04 2.47485314e-05 1.19753940e-05 4.92886466e-05
#   2.76805058e-05 1.20468198e-04 2.33058556e-04 8.83684552e-05
#   1.83572090e-04 7.63425123e-05 7.30387401e-05 8.72374512e-05
#   4.80540293e-05 2.17625653e-04 2.41102796e-04 2.38741864e-04
#   5.64860056e-05 1.38989481e-05 2.64918090e-05 6.50684015e-05
#   4.60677024e-04 1.11041700e-04 2.59462558e-05 2.35733605e-05
#   8.46601906e-05 2.93755129e-05 3.66101231e-05 5.16164328e-05
#   5.03280244e-05 2.03747168e-05 3.87701693e-05 3.61391503e-05
#   4.73960899e-05 6.52079179e-05 4.36220325e-05 7.11029497e-05
#   5.82173452e-05 5.35259969e-05 3.71648093e-05 4.22415978e-05
#   7.31751861e-05 4.48367136e-05 7.09517553e-05 7.48834864e-05
#   3.21735242e-05 2.36692340e-05 4.41810444e-05 2.16330172e-05
#   3.56254823e-05 6.03925873e-05 5.66807030e-05 4.83036129e-05
#   1.19146483e-04 8.73906683e-05 2.17990710e-05 1.10298679e-04
# ...

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02113799', 'standard_poodle', 0.64104044), ('n02099601', 'golden_retriever', 0.12503229), ('n02093647', 'Bedlington_terrier', 0.031553745), ('n02099712', 'Labrador_retriever', 0.01729503), ('n02113712', 'miniature_poodle', 0.016883126)]]

# %%
predictions=mobile.predict(final_image)

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02113799', 'standard_poodle', 0.64104044), ('n02099601', 'golden_retriever', 0.12503229), ('n02093647', 'Bedlington_terrier', 0.031553745), ('n02099712', 'Labrador_retriever', 0.01729503), ('n02113712', 'miniature_poodle', 0.016883126)]]
